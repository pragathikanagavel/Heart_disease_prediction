# %% [markdown]
# # Heart Disease Prediction
#
# ## 1. Data Collection and Understanding
#
# This notebook loads the UCI Heart Disease dataset and performs the first data inspection.

# %%
from ucimlrepo import fetch_ucirepo

heart_disease = fetch_ucirepo(id=45)
print(heart_disease.data.features.head())
print(heart_disease.data.targets.head())
print(heart_disease.variables[['name', 'role', 'type']].head(20))
